# %% [markdown]
# # **Importing Necessary Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re
from nltk.stem import WordNetLemmatizer 
from textblob import TextBlob
lemmatizer = WordNetLemmatizer()

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
cd drive/MyDrive/'Colab Notebooks'
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %% [markdown]
# # Importing dataset

# %%
df=pd.read_csv('chrome_reviews.csv')

# %%
df.head()
# Out:
#      ID                                         Review URL  \
# 0  3886  https://play.google.com/store/apps/details?id=...
# 1  3887  https://play.google.com/store/apps/details?id=...
# 2  3888  https://play.google.com/store/apps/details?id=...
# 3  3889  https://play.google.com/store/apps/details?id=...
# 4  3890  https://play.google.com/store/apps/details?id=...
#
#                                              Text  Star  Thumbs Up  \
# 0                      This is very helpfull aap.     5          0
# 1                                            Good     3          2
# 2  Not able to update. Neither able to uninstall.     1          0
# 3                                        Nice app     4          0
# 4                               Many unwanted ads     1          0
#
#           User Name Developer Reply        Version Review Date  \
# 0  INDIAN Knowledge             NaN  83.0.4103.106  2020-12-19
# 1  Ijeoma Happiness             NaN  85.0.4183.127  2020-12-19
# 2  Priti D BtCFs-29             NaN  85.0.4183.127  2020-12-19
# 3        Ajeet Raja             NaN  77.0.3865.116  2020-12-19
# 4           Rams Mp             NaN   87.0.4280.66  2020-12-19
#
#                App ID
# 0  com.android.chrome
# 1  com.android.chrome
# 2  com.android.chrome
# 3  com.android.chrome
# 4  com.android.chrome

# %% [markdown]
# Checking null values

# %%
df.isnull().sum()
# Out:
# ID                    0
# Review URL            0
# Text                  1
# Star                  0
# Thumbs Up             0
# User Name             0
# Developer Reply    7109
# Version              85
# Review Date           0
# App ID                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7204 entries, 0 to 7203
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               7204 non-null   int64
#  1   Review URL       7204 non-null   object
#  2   Text             7203 non-null   object
#  3   Star             7204 non-null   int64
#  4   Thumbs Up        7204 non-null   int64
#  5   User Name        7204 non-null   object
#  6   Developer Reply  95 non-null     object
#  7   Version          7119 non-null   object
#  8   Review Date      7204 non-null   object
#  9   App ID           7204 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 562.9+ KB

# %%
df.nunique()
# Out:
# ID                 7204
# Review URL         7204
# Text               4795
# Star                  5
# Thumbs Up            38
# User Name          7099
# Developer Reply      89
# Version             111
# Review Date          68
# App ID                1
# dtype: int64

# %% [markdown]
# Downloading Natural language tool kit

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/omw-1.4.zip.
# True

# %%
stop_words = set(stopwords.words('english'))
stop_words.remove('not')
stop_words.remove('no')

# %%
clean_text =[]
for review in df['Text']:
    review= re.sub(r'[^\w\s]', '', str(review))
    review = re.sub(r'\d','',review)
    review_token = word_tokenize(review.lower().strip()) 
    #convert reviews into lower case and strip leading and tailing spaces followed by spliting sentnece into words
    review_without_stopwords=[]
    for token in review_token:
        if token not in stop_words:
            token= lemmatizer.lemmatize(token)
            review_without_stopwords.append(token)
    cleaned_review = " ".join(review_without_stopwords)
    clean_text.append(cleaned_review)

# %%
df["cleaned_review"] = clean_text
Single_star_reviews = df[df.Star ==1]

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
sia = SentimentIntensityAnalyzer()
senti_list = []

for i in Single_star_reviews["cleaned_review"]:
    score = sia.polarity_scores(i)
    blob_score = TextBlob(i).sentiment.polarity
    if (score['pos'] >= 0.7):
        senti_list.append('Positive')
    else:
        senti_list.append('Negative/Neutral')
        
Single_star_reviews["sentiment"]= senti_list
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
Single_star_reviews.tail(15)
# Out:
#           ID                                         Review URL  \
# 7117  684905  https://play.google.com/store/apps/details?id=...
# 7123  684911  https://play.google.com/store/apps/details?id=...
# 7151  684939  https://play.google.com/store/apps/details?id=...
# 7152  684940  https://play.google.com/store/apps/details?id=...
# 7170  684958  https://play.google.com/store/apps/details?id=...
# 7171  684959  https://play.google.com/store/apps/details?id=...
# 7185  684973  https://play.google.com/store/apps/details?id=...
# 7188  684976  https://play.google.com/store/apps/details?id=...
# 7193  684981  https://play.google.com/store/apps/details?id=...
# 7195  684983  https://play.google.com/store/apps/details?id=...
# 7196  684984  https://play.google.com/store/apps/details?id=...
# 7197  684985  https://play.google.com/store/apps/details?id=...
# 7198  684986  https://play.google.com/store/apps/details?id=...
# 7200  684988  https://play.google.com/store/apps/details?id=...
# 7203  684991  https://play.google.com/store/apps/details?id=...
#
#                                                    Text  Star  Thumbs Up  \
# 7117                                        Not intrast     1          0
# 7123  I despise the way the tabs were changed. So in...     1          0
# 7151                            No good its not updated     1          0
# 7152                         Its stalled! Won't update!     1          0
# 7170                                 Not able to update     1          0
# 7171                                              Worst     1          0
# 7185  Quit moving the navigation around, its annoyin...     1          1
# 7188                                           NET slow     1          0
# 7193                          Microsoft gang forever 😤💙     1          0
# 7195  Chrome is good, I trust this update will make ...     1          0
# 7196       It will not let me update Samsung Galaxy a20     1          0
# 7197  Every time updates screw things up, I mean thi...     1          0
# 7198  for every search google translator pops up, ev...     1          0
# 7200                                      Bad version 😔     1          0
# 7203  After update it lag and always slow same goes ...     1          0
#
#                 User Name Developer Reply        Version Review Date  \
# 7117            Hanu Hanu             NaN   89.0.4389.72  2021-03-05
# 7123             Zahari25             NaN   89.0.4389.72  2021-03-05
# 7151         Aditya gamer             NaN   87.0.4280.86  2021-03-05
# 7152        Theone Kaiser             NaN  88.0.4324.152  2021-03-05
# 7170       Mahender Kumar             NaN  79.0.3945.116  2021-03-05
# 7171         Shibayan Das             NaN  83.0.4103.106  2021-03-05
# 7185         Justin Mills             NaN  88.0.4324.181  2021-03-05
# 7188          Afzal Afini             NaN  83.0.4103.101  2021-03-05
# 7193  A A A A A A A A POQ             NaN  74.0.3729.136  2021-03-05
# 7195      Harry W Kendall             NaN  88.0.4324.181  2021-03-05
# 7196        Mary Ferguson             NaN  84.0.4147.111  2021-03-05
# 7197               TBGood             NaN  88.0.4324.152  2021-03-05
# 7198           Dark World             NaN  88.0.4324.181  2021-03-05
# 7200         निशान्त सिंह             NaN  88.0.4324.181  2021-03-05
# 7203           Hanin Amni             NaN   88.0.4324.93  2021-03-05
#
#                   App ID                                     cleaned_review  \
# 7117  com.android.chrome                                        not intrast
# 7123  com.android.chrome  despise way tab changed inconvenient clunky gr...
# 7151  com.android.chrome                                no good not updated
# 7152  com.android.chrome                                stalled wont update
# 7170  com.android.chrome                                    not able update
# 7171  com.android.chrome                                              worst
# 7185  com.android.chrome  quit moving navigation around annoying edit un...
# 7188  com.android.chrome                                           net slow
# 7193  com.android.chrome                             microsoft gang forever
# 7195  com.android.chrome               chrome good trust update make better
# 7196  com.android.chrome                      not let update samsung galaxy
# 7197  com.android.chrome  every time update screw thing mean think make ...
# 7198  com.android.chrome  every search google translator pop even though...
# 7200  com.android.chrome                                        bad version
# 7203  com.android.chrome       update lag always slow go googleee want work
#
#              sentiment
# 7117  Negative/Neutral
# 7123  Negative/Neutral
# 7151  Negative/Neutral
# 7152  Negative/Neutral
# 7170  Negative/Neutral
# 7171  Negative/Neutral
# 7185  Negative/Neutral
# 7188  Negative/Neutral
# 7193  Negative/Neutral
# 7195          Positive
# 7196  Negative/Neutral
# 7197  Negative/Neutral
# 7198  Negative/Neutral
# 7200  Negative/Neutral
# 7203  Negative/Neutral

# %%
positive_review_with_1_star = Single_star_reviews[Single_star_reviews.sentiment == 'Positive']
positive_review_with_1_star.drop("cleaned_review",axis = 1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
positive_review_with_1_star.head()
# Out:
#        ID                                         Review URL  Text  Star  \
# 101  4113  https://play.google.com/store/apps/details?id=...  Good     1
# 158  4143  https://play.google.com/store/apps/details?id=...  Good     1
# 291  5251  https://play.google.com/store/apps/details?id=...    Ok     1
# 310  5842  https://play.google.com/store/apps/details?id=...  Best     1
# 312  5844  https://play.google.com/store/apps/details?id=...  Good     1
#
#      Thumbs Up          User Name Developer Reply        Version Review Date  \
# 101          0      Sohail Soomro             NaN  74.0.3729.136  2020-12-21
# 158          0      Md Rubel khan             NaN            NaN  2020-12-21
# 291          0      Rajesh Prabhu             NaN  76.0.3809.111  2020-12-21
# 310          0  Vasava Govindbhai             NaN   67.0.3396.87  2020-12-22
# 312          0         Prem Kumar             NaN   80.0.3987.99  2020-12-22
#
#                  App ID sentiment
# 101  com.android.chrome  Positive
# 158  com.android.chrome  Positive
# 291  com.android.chrome  Positive
# 310  com.android.chrome  Positive
# 312  com.android.chrome  Positive

# %%
positive_review_with_1_star.to_csv('output.csv')
